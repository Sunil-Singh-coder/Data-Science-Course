# %%
import matplotlib.pyplot as plt
import numpy as np
# we can use HISTOGRAM To distribute frequency on data sets 

score=[80,70,75,60,62,61,55,52,50,45,39,90,99,35,23,20,35,33]
plt.hist(score,bins=[10,20,30,40,50,60],edgecolor="black")
plt.axvline(np.mean(score),color="red")  # scatter
plt.grid(True)
