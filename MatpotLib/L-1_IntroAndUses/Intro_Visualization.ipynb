# %%
# Data Visualization 
# Data visualization is the bridge  between raw data and human understanding 

# Exploratory and Explanatory
# Exploratory -------> YOU 
# Explanatory  ---- > Client ko dekhne ke liye 

# Basic Principles of Good Visualizations 
# 1.Clarity
# 2.Context
# 3.Focus
# 4.Storytelling
# 5 Accessibility
