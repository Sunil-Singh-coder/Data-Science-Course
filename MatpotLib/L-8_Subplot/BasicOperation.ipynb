# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7,8,9]
x1= [i*2 for i in x]
x2= [i*i for i in x]
y3= [0.5*i  for i in x]
y4= [10-i for i in x]

# %%
fig, axs= plt.subplots(2,2,figsize=(7,5))
axs[0][0].plot(x,x1)
axs[0][0].set_title("Double of a number ")
axs[0][1].plot(x,x2)
axs[0][0].set_title("Square of a number ")

plt.suptitle("comarision")
fig.savefig("myplots.png")
