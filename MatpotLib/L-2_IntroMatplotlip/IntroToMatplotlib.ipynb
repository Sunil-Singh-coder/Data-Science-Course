# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[5,10,4])

# %%
# Sachin Tendulkar Data
years= [2000,2001,2002,2003,2005,2006,2007,2008,2009,2010]
# runs=[500,700,1100,1500,1200,1800,2000,3000,1500,3000]
# plt.plot(years,runs)
# plt.xlabel("Years")
# plt.ylabel("Run")
# plt.title("Yearly run ")

# %%
# add multiple lines in plot
years= [2000,2001,2002,2003,2005,2006,2007,2008,2009,2010]
kohli=[500,700,1100,1500,1200,1800,2000,3000,3200,3500]
sachin=[600,700,1200,1000,1500,2800,3000,2500,1500,1000]
plt.plot(years, kohli, label= "Virat Kohli")
plt.plot(years, sachin, label= "Sachin")

# we can also do but practise for prsenting name 
plt.legend(["Kohli","Years")

plt.xlabel("Years")
plt.ylabel("Run")
plt.title(" Performance Comparison ")
# plt.legend()
plt.show()
