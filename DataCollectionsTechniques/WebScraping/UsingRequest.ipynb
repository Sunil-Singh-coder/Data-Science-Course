# %%
import requests

# %%
# url="https://quotes.toscrape.com/page/10/"
# response= requests.get(url)

# %%
# print(response.text)
# print(response.content)
# print(response.status_code)  # 200 - > means ok (you are able to)

# %%
for i in range(11):
    with open(f"WebScraoing/html/page1.html{i}","w",encoding="utf-8") as f:
        a=requests.get(f"https://quotes.toscrape.com/page/{i}/")
        f.write(a.text)
        print("successful ")
# Out:
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
# successful
