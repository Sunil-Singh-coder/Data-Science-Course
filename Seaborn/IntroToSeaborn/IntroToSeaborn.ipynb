# %%
# Intro to seaborn  
# seaborn adds high-level features like automatic styling themes , color palettes
# and dataFrame  intergartion

# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="dark")

# %%
arr = np.array([10,20,25,30,40,50,60,70,80,90])
value= np.sin(arr)
sns.lineplot(x=arr,y=value)
# Out:
# <Axes: >
