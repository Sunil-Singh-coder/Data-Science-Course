# %%
import pandas as pd

df= pd.read_excel("data.xlsx")
print(df)

#  .astype()   
# we can convert  column data types
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# 1  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 2   Noori   NaN   2333.0            noori@gmail.com     30.0
# 3   rohan  41.0  10000.0                        NaN     50.0
# 4   anshu  20.0      NaN            anshu@gmail.com     60.0

# %%
df1=df.dropna().copy()
print(df1)
# df1.info()
df1["Salary"]= df1["Salary"].astype(int)  #---- > convert data types into any type
df1.info()
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     1 non-null      object
#  1   Id       1 non-null      float64
#  2   Salary   1 non-null      int64
#  3   Email    1 non-null      object
#  4   PSI no.  1 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 48.0+ bytes
