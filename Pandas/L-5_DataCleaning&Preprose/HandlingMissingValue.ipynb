# %%
import pandas as pd

df= pd.read_excel("data.xlsx")
print(df)
# All Handling function give only view not copy
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# 1  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 2   Noori   NaN   2333.0            noori@gmail.com     30.0
# 3   rohan  41.0  10000.0                        NaN     50.0
# 4   anshu  20.0      NaN            anshu@gmail.com     60.0

# %%
# chexk null block 
# print(df.isnull())
# df.isnull().sum()


# drop missing data 
df.dropna()     #--- drop the null row
# df.dropna(axis=1)     #--- drop the null column
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0

# %%
# Filll missing Data
# df.fillna(0)    #----- > fill null place with 0 value 
# df["Salary"].fillna(df["Salary"].mean())



# fill by  backword and forwand value 
# df.ffill()
# df.bfill()

# print(df)
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# 1  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 2   Noori   NaN   2333.0            noori@gmail.com     30.0
# 3   rohan  41.0  10000.0                        NaN     50.0
# 4   anshu  20.0      NaN            anshu@gmail.com     60.0
