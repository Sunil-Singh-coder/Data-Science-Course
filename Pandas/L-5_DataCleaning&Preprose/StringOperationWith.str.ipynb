# %%
# String operation with .str
# we can use string operation on pandas a spython not all 
import pandas as pd

df= pd.read_excel("data.xlsx")
print(df)
# All Handling function give only view not copy
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# 1  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 2   Noori   NaN   2333.0            noori@gmail.com     30.0
# 3   rohan  41.0  10000.0                        NaN     50.0
# 4   anshu  20.0      NaN            anshu@gmail.com     60.0

# %%
df["Name"].str.lower()
df["Name"].str.upper()
# Out:
# 0    SUNIL
# 1    AFREEN
# 2     NOORI
# 3     ROHAN
# 4     ANSHU
# Name: Name, dtype: object

# %%
df["Name"].str.contains("Noori",case=False)   # show contain or not

print(type(df["Name"].str.contains("Noori",case=False) ))  # show contain or not
# Out:
# <class 'pandas.core.series.Series'>

# %%
df["Email"].str.split("@")[0]     # split string in pandas and return a list
# Out:
# ['singhsunil34500', 'gmail.com']
