# %%
 import pandas as pd
df= pd.read_excel("data.xlsx.xlsx")
print(df)
# Out:
#      Name    Id   Salary                      Email  PSI no.
# 0  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0
# 1  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 2   Noori   NaN   2333.0            noori@gmail.com     30.0
# 3   rohan  41.0  10000.0                        NaN     50.0
# 4   anshu  20.0      NaN            anshu@gmail.com     60.0
# 5  Afreen   7.0  10000.0      sfreheeh222@gmail.com      NaN
# 6  Sunil   55.0  20000.0  singhsunil34500@gmail.com     20.0

# %%
# Detect duplicate row true or false 
df.duplicated()     # check is dupliacte or not 

df.drop_duplicates()  #   remove duplicate row 

# checked specific column 
df.duplicated(subset=["Salary"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# dtype: bool
