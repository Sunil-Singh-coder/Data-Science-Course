# %%
import pandas as pd

data1= pd.DataFrame({"Name" : ["Sunil","Rohan"] ,"Score": [23,24]})
data2= pd.DataFrame({"Name" : ["Sunil","Rohan"],"Age": [35,43]})
print(data1)
# Out:
#     Name  Score
# 0  Sunil     23
# 1  Rohan     24

# %%
pd.concat([data1,data2])  #---> concat on the basic of row 
# pd.concat([data1,data2],axis=1)  # ---> concat on comuln
# Out:
#     Name  Score   Age
# 0  Sunil   23.0   NaN
# 1  Rohan   24.0   NaN
# 0  Sunil    NaN  35.0
# 1  Rohan    NaN  43.0
