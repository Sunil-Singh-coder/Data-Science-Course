# %%
import pandas as pd 

df = pd.read_csv("data.csv")
print(df)
# Out:
#     ID           Name  Age  Salary              Department
# 0  101    Sunil Singh   28   50000        Computer Science
# 1  102   Priya Sharma   26   55000  Mechanical Engineering
# 2  103    Rahul Verma   24   52000  Electrical Engineering
# 3  104  Anjali Kumari   30   60000       Civil Engineering
# 4  105    Rohan Yadav   27   53000                      IT

# %%
df[df["Salary"]>53000]
# print(df)
# Out:
#     ID           Name  Age  Salary              Department
# 1  102   Priya Sharma   26   55000  Mechanical Engineering
# 3  104  Anjali Kumari   30   60000       Civil Engineering

# %%
# write in csv   to create a new csv file by usinf this method
# df.to_csv("newcsv.csv")
df.to_csv("newcsv.csv",index=False)     # index will remove from here

# %%
# read from excel file
df.read_exel("data.xlsx")

# write to the excel file
df.to_excel("newexcel.xlsx")

# %%
df1= pd.read_json("data.json.txt")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df1= pd.read_json("data.json.txt")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
# ...
