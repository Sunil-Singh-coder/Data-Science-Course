# %%
import pandas as pd
data={
    "name" : ["Sunil","Rohan","Anshu"],
    "age": [23,25,20],
    "city":["bagadpur","bakar","kekara"]
}
print(pd.DataFrame(data))
# Out:
#     name  age      city
# 0  Sunil   23  bagadpur
# 1  Rohan   25     bakar
# 2  Anshu   20    kekara

# %%
df=pd.DataFrame(data)
print(df.index)
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df=pd.DataFrame(data)
print(df.columns)
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
# changing the index by own 
df.index=["a","b","c"]
print(df.index)
print(df)
# df.columns(["name","age","city"])
print(df.columns)
# Out:
# Index(['a', 'b', 'c'], dtype='object')
#     name  age      city
# a  Sunil   23  bagadpur
# b  Rohan   25     bakar
# c  Anshu   20    kekara
# Index(['name', 'age', 'city'], dtype='object')
