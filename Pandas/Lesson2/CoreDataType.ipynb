# %%
# panads is bulit on two main data structure 
# 1.Series
# 2.DataFrame

# %%
# Series is a 1D labebeld Array
import pandas as pd
s= pd.Series([2,3,4,3])
print(s)
# Out:
# 0    2
# 1    3
# 2    4
# 3    3
# dtype: int64

# %%
s2= pd.Series(["sunil","archana","Rohan"])
print(s2)
# Out:
# 0      sunil
# 1    archana
# 2      Rohan
# dtype: object

# %%
# you can also defines a custom index 
s= pd.Series([5,10,15],index=["a","b","c"])
print(s)
# Out:
# a     5
# b    10
# c    15
# dtype: int64
