# %%
import pandas as pd
print(pd.read_excel("data.xlsx"))
# Out:
#      Name  Age  Rollno  id
# 0  Sunil   221      22  21
# 1   Rohan   20      31  21
# 2   noori   21      24  21
# 3  Afreen   22       7  21
# 4    umme   22      58  21

# %%
df=pd.read_excel("data.xlsx")

# %%
#  You can also raed CSV file and make a data frameabs
# df= pd.read_csv("data.csv") 
# csv file is light  weight than xl file

# %%
df= pd.read_json("data.json.txt")
print(df)
# Out:
#     name  Age       id
# 0  Harry   45  Itmai16
# 1  Harry   45  Itmai16
