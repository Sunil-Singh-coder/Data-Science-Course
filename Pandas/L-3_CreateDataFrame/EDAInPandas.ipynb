# %%
# EDA is very Essentail in Data science 
import pandas as pd
data={
    "name" : ["ss","rr" ,"ee","sds","sdds","sdsd","ss","rr" ,"ee","sds","sdds","sdsd"],
    "age" :[23,34,35,34,34,5,6,3,4,4,6,4]
}
df = pd.DataFrame(data)
# print(df)
# 1.
# print(df.head())
# print(df.tail())
# print(df.info())
# df.describe()
print(df.columns)
print(df.shape)


# df.head
# Out:
# Index(['name', 'age'], dtype='object')
# (12, 2)
