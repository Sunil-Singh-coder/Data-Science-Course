# %%
import numpy as np
import pandas as pd

# %%
arr= np.array([
    ["Sunil" ,55],
    ["Rohan" ,42],
    ["Afreen" ,7]]
             )
print(pd.DataFrame(arr,columns=["Name","Age"]))
# Out:
#      Name Age
# 0   Sunil  55
# 1   Rohan  42
# 2  Afreen   7
