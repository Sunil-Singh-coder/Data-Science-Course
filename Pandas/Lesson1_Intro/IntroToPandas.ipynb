# %%
#  pandas in data science
# pandas library is used to data manipualation , cleaning and analysis

import pandas as pd 

# •	Use Pandas when working with structured data.
# •	It’s the Swiss Army knife of data science.
