# %%
# 1.
import numpy as np

# %%
arr= np.array([1,3,5,2])

# %%
print(np.mean(arr))
# Out:
# 2.25

# %%
print(np.min(arr))
# Out:
# 2

# %%
print(np.max(arr))
# Out:
# 5

# %%
print(np.std(arr))
# Out:
# 1.479019945774904

# %%
print(np.var(arr))
# Out:
# 2.1875

# %%
print(np.sum(arr))
# Out:
# 11

# %%
print(np.prod(arr))
# Out:
# 30

# %%
print(np.median(arr))
# Out:
# 2.5

# %%
print(np.argmin(arr))
# Out:
# 0

# %%
print(np.argmax(arr))
# Out:
# 2

# %%
print(np.unique(arr))
# Out:
# [1 2 3 5]

# %%
print(np.diff(arr))
# Out:
# [ 2  2 -3]

# %%
print(np.linspace(arr))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(np.linspace(arr))
#
# TypeError: linspace() missing 1 required positional argument: 'stop'

# %%
print(np.exp(arr))
# Out:
# [  2.71828183  20.08553692 148.4131591    7.3890561 ]
