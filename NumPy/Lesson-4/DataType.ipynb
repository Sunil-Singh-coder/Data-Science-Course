# %%
# Data type in numpy 
import numpy as np 
arr= np.array([1,2,2,3,])
print(arr.dtype)
# Out:
# int64

# %%
arr.astype("float64")
# Out:
# array([1., 2., 2., 3.])

# %%
arr= np.array([2,32,3,2], dtype="float64")
arr
# Out:
# array([ 2., 32.,  3.,  2.])

# %%
arr
# Out:
# array([ 2., 32.,  3.,  2.])

# %%
print(arr.dtype)
# Out:
# float64

# %%
con_into =arr.astype("int64")

# %%
con_into
# Out:
# array([ 2, 32,  3,  2])

# %%
# checking memory uses 
arr1= np.array([2,32,2,2], dtype="int32")
arr2= np.array([2,32,2,2], dtype="int64")
print(arr1.nbytes)
print(arr2.nbytes)
# Out:
# 16
# 32

# %%
#  string in numpy
# basically we do not use string in numpy becoz it is less effiesient
arrStr= np.array(["sunil" ,"sona" , "meka"] , )
print(arrStr)
print(arrStr.dtype)
# Out:
# ['sunil' 'sona' 'meka']
# <U5

# %%
# complex number in numpy
arr1 = np.array([1+2j, 2+3j,3+4j], dtype="complex64")
arr2 = np.array([1+2j, 2+3j,3+4j],dtype="complex128")
print(arr)
print(arr.dtype)
# Out:
# [1.+2.j 2.+3.j 3.+4.j]
# complex128

# %%
#  object data types in numypy
arr= np.array([{'a':1} , [2,3,4] ,"sunil"],dtype= "object"  )
print(arr[0]['a'])
print(arr.dtype)
# Out:
# 1
# object
