# %%
#  3 D Array 
import numarr.shappy as np
arr= np.array(
    [  [ [2,4,5] ,[8,2,6]] ,
       [[8,4,9] , [2,4,3]]
    ]
)
print(e)
# Out:
# (2, 2, 3)

# %%
print(arr[0][1][1])
print(arr[:,0,: ])
# Out:
# 2
# [[2 4 5]
#  [8 4 9]]

# %%
print(arr[:,0,0])
print(arr[1,0,:])
# Out:
# [2 8]
# [8 4 9]

# %%
fla=arr[:,0]
print(fla)
# Out:
# [[2 4 5]
#  [8 4 9]]

# %%
# changing along the axis ----
# arr= np.array(
#     [  [ [2,4,5] ,[8,2,6]] ,
#        [[8,4,9] , [2,4,3]]
#     ]
# )

# arr[0,:,1]=2
arr[:,0]=2

# arr[:,:,:]=0
print(arr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       1 # changing along the axis ----
#       2 # arr= np.array(
#       3 #     [  [ [2,4,5] ,[8,2,6]] ,
#    (...)
#       7
#       8 # arr[0,:,1]=2
# ----> 9 arr[:,0]=2
#      11 # arr[:,:,:]=0
#      12 print(arr)
#
# NameError: name 'arr' is not defined

# %%
import numpy as np
arr= np.array(
    [  [ [2,4,5] ,[8,2,6]] ,
       [[8,4,9] , [2,4,3]]
    ]
)
print(arr[0,:,:])
print(arr[:,0,0])
# Out:
# [[2 4 5]
#  [8 2 6]]
# [2 8]
