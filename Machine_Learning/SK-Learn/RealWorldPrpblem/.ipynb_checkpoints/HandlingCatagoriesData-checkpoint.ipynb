# %%
from sklearn.model_selection import StratifiedShuffleSplit
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("housing.csv")

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size=0.1,random_state=42)
for train_index,test_index in split.split(df,df["ocean_proximity"]):
    train_set=df.iloc[train_index]
    test_set=df.iloc[test_index]
train_set
# test_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10553    -117.71     33.64                14.0       2945.0           356.0
# 15125    -116.86     32.87                17.0       5799.0           921.0
# 12905    -121.33     38.61                21.0       2453.0           518.0
# 6453     -118.06     34.12                25.0       3891.0           848.0
# 15251    -117.27     32.98                17.0       1853.0           392.0
# ...          ...       ...                 ...          ...             ...
# 14439    -117.24     32.80                30.0       1917.0           462.0
# 17958    -121.98     37.33                35.0       1907.0           326.0
# 9470     -123.79     39.44                16.0       2017.0           423.0
# 19164    -122.69     38.34                16.0       1683.0           341.0
# 20249    -119.25     34.21                12.0      15201.0          2418.0
#
# ...

# %%
# split the label and feature from the main data for prepare for the training the data


housing=   train_set.drop("median_house_value",axis=1)
housing_lables=  test_set["median_house_value"]
# housing
# housing_lables

# %%
# Handling missing  data  by using pandas 
# 1---> Drop rows with missing values 
# 2--> Drop the Entire column 
# 3---> Impute missing Values(recommended)

# %%
# We use option 3 by using Simple Imputer 
from sklearn.impute import SimpleImputer 
imputer = SimpleImputer(strategy="median")
housing_num= housing.select_dtypes(include=[np.number])
imputer.fit(housing_num)
# print(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
# X= imputer.transform(housing_num)
# Out:
# array([[-1.1771e+02,  3.3640e+01,  1.4000e+01, ...,  1.2930e+03,
#          3.3500e+02,  8.1110e+00],
#        [-1.1686e+02,  3.2870e+01,  1.7000e+01, ...,  2.6300e+03,
#          8.4300e+02,  5.0524e+00],
#        [-1.2133e+02,  3.8610e+01,  2.1000e+01, ...,  1.3260e+03,
#          5.0500e+02,  2.7079e+00],
#        ...,
#        [-1.2379e+02,  3.9440e+01,  1.6000e+01, ...,  1.1770e+03,
#          4.1400e+02,  3.2171e+00],
#        [-1.2269e+02,  3.8340e+01,  1.6000e+01, ...,  8.8000e+02,
#          3.2700e+02,  3.2857e+00],
#        [-1.1925e+02,  3.4210e+01,  1.2000e+01, ...,  7.1320e+03,
#          2.2510e+03,  5.6756e+00]])
