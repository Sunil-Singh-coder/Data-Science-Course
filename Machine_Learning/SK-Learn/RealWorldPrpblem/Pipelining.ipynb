# %%
from sklearn.model_selection import StratifiedShuffleSplit
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("housing.csv")

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size=0.1,random_state=42)
for train_index,test_index in split.split(df,df["ocean_proximity"]):
    train_set=df.iloc[train_index]
    test_set=df.iloc[test_index]
# train_set
# test_set

# %%
housing=   train_set.drop("median_house_value",axis=1)
housing_lables=  test_set["median_house_value"]

# %%
housing= housing.drop("ocean_proximity",axis=1)
housing
demo=train_set.drop("ocean_proximity",axis=1)
demo
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10553    -117.71     33.64                14.0       2945.0           356.0
# 15125    -116.86     32.87                17.0       5799.0           921.0
# 12905    -121.33     38.61                21.0       2453.0           518.0
# 6453     -118.06     34.12                25.0       3891.0           848.0
# 15251    -117.27     32.98                17.0       1853.0           392.0
# ...          ...       ...                 ...          ...             ...
# 14439    -117.24     32.80                30.0       1917.0           462.0
# 17958    -121.98     37.33                35.0       1907.0           326.0
# 9470     -123.79     39.44                16.0       2017.0           423.0
# 19164    -122.69     38.34                16.0       1683.0           341.0
# 20249    -119.25     34.21                12.0      15201.0          2418.0
#
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
mypipeline = Pipeline([
          ("impute",SimpleImputer(strategy='median')),
           ("scale",StandardScaler())
            
           ])

# %%
housing=mypipeline.fit_transform(housing)
demo=train_set.drop("ocean_proximity",axis=1)
demo = demo.drop("median_house_value",axis=1)
# demo
housing_df= pd.DataFrame(housing,columns=demo.columns,index=demo.index)
housing_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10553   0.932454 -0.934628           -1.167228     0.147201       -0.433631
# 15125   1.357073 -1.294713           -0.928799     1.469467        0.932772
# 12905  -0.875920  1.389556           -0.610895    -0.080744       -0.041848
# 6453    0.757612 -0.710160           -0.292991     0.585486        0.756228
# 15251   1.152257 -1.243273           -0.928799    -0.358725       -0.346568
# ...          ...       ...                 ...          ...             ...
# 14439   1.167243 -1.327448            0.104389    -0.329074       -0.177279
# 17958  -1.200628  0.790974            0.501770    -0.333707       -0.506183
# 9470   -2.104815  1.777700           -1.008275    -0.282744       -0.271597
# 19164  -1.555309  1.263293           -1.008275    -0.437487       -0.469907
# 20249   0.163146 -0.668072           -1.326180     5.825440        4.553134
#
#        population  households  median_income
# ...
